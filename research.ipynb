# %%
1 + 2
# Out:
# 3

# %%
# !pip install langchain-gigachat langchain python-dotenv -q
# Out:
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import getpass
import os
from dotenv import find_dotenv, load_dotenv

load_dotenv(find_dotenv())

if "GIGACHAT_CREDENTIALS" not in os.environ:
    os.environ["GIGACHAT_CREDENTIALS"] = getpass.getpass("Credentials от GigaChat")

from langchain_gigachat.chat_models import GigaChat

llm = GigaChat(
    temperature=0.1,
    verify_ssl_certs=False,
    timeout=6000,
    model="GigaChat-Pro"
)

# %%
from langchain_core.messages import HumanMessage

content = llm.invoke([
    HumanMessage(
        content="Что умеешь?"
    )
]).content
print(content)
# Out:
# Вот список основных вещей, которыми я могу тебе помочь:
#
# ### 📝 Работа с текстом:
# - Анализ текста: грамматика, стилистика, смысловая структура.
# - Генерация уникальных текстов любого стиля и жанра (стихи, рассказы, статьи).
# - Перевод и адаптация текстов на разные языки.
# - Помощь в написании писем, эссе, резюме и других документов.
# - Редактирование и улучшение уже готовых материалов.
#
# ### 🧮 Математика и логика:
# - Решение математических задач любой сложности от простых уравнений до сложных интегралов и дифференциальных уравнений.
# - Логические головоломки и задачи на смекалку.
# - Объяснение понятий и методов математики и статистики.
#
# ### 💻 Программирование:
# - Написание и отладка программного кода на популярных языках программирования (Python, JavaScript, C++, SQL и др.).
# - Создание алгоритмов и структур данных.
# - Консультации по вопросам разработки ПО и веб-приложений.
#
# ### 🎨 Творчество и креативность:
# - Генерация идей для проектов, стартапов, сценариев фильмов и книг.
# - Разработка персонажей, сюжетов и концепций.
# - Подбор интересных тем для обсуждения и творчества.
#
# ### 🤔 Обсуждение и философия:
# - Глубокие беседы на философские темы, обсуждение мировоззренческих вопросов.
# - Рассуждения о культуре, искусстве, науке и технологиях.
# - Обмен мнениями и взглядами на актуальные события и тренды.
#
# ### 🌐 Общение и помощь:
# - Просто поговорить обо всём на свете.
# - Поддержка и мотивация в трудные моменты.
# - Ответы на любые вопросы, где есть место любопытству и интересу.
#
# Если хочешь попробовать что-то конкретное — пиши!
