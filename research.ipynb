# %%
import getpass
import os
from dotenv import find_dotenv, load_dotenv

load_dotenv(find_dotenv())

if "GIGACHAT_CREDENTIALS" not in os.environ:
    os.environ["GIGACHAT_CREDENTIALS"] = getpass.getpass("Credentials от GigaChat")

from langchain_gigachat.chat_models import GigaChat

llm = GigaChat(
    temperature=0.1,
    verify_ssl_certs=False,
    timeout=6000,
    model="GigaChat-Pro"
)

# %%
from langchain_core.messages import HumanMessage, SystemMessage, AIMessage

messages = [
    SystemMessage(content="Ты HR."),
    HumanMessage(content="Хочу устроиться на работу")
]

# %%
print(llm.invoke(messages).content)
# Out:
# Это здорово! Чтобы успешно найти подходящую вакансию и получить работу, рекомендую пройти следующие шаги:
#
# ### 1. Определите свою цель
# - Подумайте, какая работа вам интересна: профессия, сфера деятельности, уровень ответственности, график работы (полный день, удалёнка, частичная занятость).
# - Оцените свои сильные стороны, опыт, образование и навыки.
#
# ### 2. Подготовьте резюме и сопроводительное письмо
# - Резюме должно быть чётким, структурированным и содержать всю необходимую информацию: образование, опыт работы, профессиональные достижения, ключевые навыки.
# - Сопроводительное письмо поможет подчеркнуть вашу мотивацию и объяснить, почему именно вы подходите на эту должность.
#
# ### 3. Ищите вакансии
# - Используйте сайты вакансий (например, HeadHunter, SuperJob, Авито Работа, hh.ru, Rabota.ru).
# - Посещайте ярмарки вакансий, карьерные мероприятия, форумы работодателей.
# - Обратитесь в кадровые агентства или центры занятости населения.
# - Не забывайте про рекомендации знакомых и друзей — часто лучшие предложения поступают через личные связи.
#
# ### 4. Готовьтесь к собеседованию
# - Изучите компанию, её миссию, ценности и продукты/услуги.
# - Подготовьте ответы на типичные вопросы интервьюера («Расскажите о себе», «Почему хотите работать именно здесь?»», «Какие ваши слабые стороны?».
# - Практикуйте самопрезентацию и рассказ о своём опыте.
#
# ### 5. После собеседования
# - Отправьте благодарственное письмо работодателю после встречи.
# - Следите за обратной связью от работодателя.
#
# ### Полезные советы:
# - Регулярно обновляйте своё резюме и профиль на сайтах поиска работы.
# - Участвуйте в профессиональных сообществах, посещайте тренинги и курсы повышения квалификации.
# - Будьте готовы к временному испытательному сроку или стажировке.
#
# Удачи в поиске работы! Если нужна помощь с конкретными аспектами трудоустройства, обращайтесь.

# %%
from langchain_core.language_models.chat_models import BaseChatModel


class Chat:
    def __init__(
        self,
        llm: BaseChatModel
    ):
        self.llm = llm
        self.prompt = "Ты HR."
        self.messages = []
        self.messages.append(SystemMessage(self.prompt))

    async def __call__(self, message: str) -> str:
        self.messages.append(HumanMessage(message))
        result = await self.llm.ainvoke(self.messages)
        self.messages.append(result)
        return str(result.content)
    
    def clear(self):
        self.messages.clear()
